# %%
#!git clone https://github.com/hyperconnect/TC-ResNet.git
#!pip3 install -r ./TC-ResNet/requirements/py36-gpu.txt

# %%
#cd TC-ResNet/

# %%
# train model
#! ./scripts/commands/TCResNet8Model-1.0_mfcc_40_3010_0.001_mom_l1.sh

# %%
# !git clone https://github.com/tranHieuDev23/TC-ResNet.git
# Out:
# fatal: destination path 'TC-ResNet' already exists and is not an empty directory.

# %%
cd TC-ResNet/
# Out:
# /content/TC-ResNet

# %% [markdown]
# Uncomment following 5 cells to load google speech dataset

# %%
#!mkdir dataset

# %%
#cd dataset/

# %%
#!wget http://download.tensorflow.org/data/speech_commands_v0.01.tar.gz

# %%
#!tar xvf speech_commands_v0.01.tar.gz

# %%
#cd ..

# %%
from os import listdir
from os.path import join, isfile, isdir, normpath
from multiprocessing import Pool, cpu_count
from tqdm import tqdm
import numpy as np
from itertools import zip_longest
import librosa
import random
import math
import numpy as np
from random import seed, randint
from train import get_tc_resnet_8, get_tc_resnet_14
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.models import Model, Sequential
from keras.layers import Input, Conv1D, ReLU, BatchNormalization, Add, AveragePooling1D, Dense, Flatten, Dropout, Activation
from google.colab import files

# %%
# To train entire tc-resnet--uncomment
"""
from process_data import process_file, generate_noisy_sample
def __load_audio_filenames_with_class__(root_folder):
    classes = [item for item in listdir(root_folder) if isdir(
        join(root_folder, item)) and not item.startswith('_')]
    filenames = []
    class_ids = []
    for i in range(len(classes)):
        c = classes[i]
        class_filenames = __load_audio_filenames__(join(root_folder, c))
        filenames.extend(class_filenames)
        class_ids.extend([i] * len(class_filenames))
    return filenames, class_ids, classes


def __load_audio_filenames__(root_folder):
    filenames = []
    for entry in listdir(root_folder):
        full_path = join(root_folder, entry)
        if (isfile(full_path)):
            if (entry.endswith('.wav')):
                filenames.append(full_path)
        else:
            filenames.extend(__load_audio_filenames__(full_path))
        if (len(filenames) >= 100):
            break
    return filenames


def __load_subset_filenames__(root_folder, filename):
    subset_list = []
    with open(join(root_folder, filename)) as f:
        for line in f:
            line = line.strip()
            if (len(line) == 0):
                continue
            subset_list.append(normpath(join(root_folder, line)))
    return set(subset_list)


def load_data_from_folder(root_folder):
    filenames, class_ids, classes = __load_audio_filenames_with_class__(root_folder)
    dataset_size = len(filenames)
    X_train = []
    y_train = []
    X_test = []
    y_test = []
    X_validation = []
    y_validation = []
    pool = Pool(cpu_count() - 1)
    for (results, filepath, class_id, random_roll) in tqdm(pool.imap_unordered(process_file, zip_longest(filenames, class_ids)), total=dataset_size):
        filepath = normpath(filepath)
        is_testing = 1 <= random_roll and random_roll <= 10
        is_validation = 11 <= random_roll and random_roll <= 20
        for item in results:
            if (is_testing):
                X_test.append(item)
                y_test.append(class_id)
            elif (is_validation):
                X_validation.append(item)
                y_validation.append(class_id)
            else:
                X_train.append(item)
                y_train.append(class_id)
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    X_validation = np.array(X_validation)
    y_validation = np.array(y_validation)
    return X_train, y_train, X_test, y_test, X_validation, y_validation, classes

X_train, y_train, X_test, y_test, X_validation, y_validation, classes = load_data_from_folder('dataset')
num_classes = len(classes)
print(num_classes)
(num_train, input_length, num_channel) = X_train.shape
num_test = X_test.shape[0]
num_validation = X_validation.shape[0]
model_14 = get_tc_resnet_8((input_length, num_channel), num_classes, 1.5)
model_14.compile(optimizer=Adam(),loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#checkpoint_cb = ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.h5', save_weights_only=True, period=5)
model_14.fit(x=X_train, y=y_train, batch_size=1024, epochs=100, validation_data=(X_test, y_test))#, callbacks=[checkpoint_cb])
print(model_14.evaluate(X_validation, y_validation))
model_14.save_weights('weights.h5')
files.download('weights.h5') 
"""
# Out:
# "\nfrom process_data import process_file, generate_noisy_sample\ndef __load_audio_filenames_with_class__(root_folder):\n    classes = [item for item in listdir(root_folder) if isdir(\n        join(root_folder, item)) and not item.startswith('_')]\n    filenames = []\n    class_ids = []\n    for i in range(len(classes)):\n        c = classes[i]\n        class_filenames = __load_audio_filenames__(join(root_folder, c))\n        filenames.extend(class_filenames)\n        class_ids.extend([i] * len(class_filenames))\n    return filenames, class_ids, classes\n\n\ndef __load_audio_filenames__(root_folder):\n    filenames = []\n    for entry in listdir(root_folder):\n        full_path = join(root_folder, entry)\n        if (isfile(full_path)):\n            if (entry.endswith('.wav')):\n                filenames.append(full_path)\n        else:\n            filenames.extend(__load_audio_filenames__(full_path))\n        if (len(filenames) >= 100):\n            break\n    return filenames\n\n\ndef __load_subset_filenames__(root_folder, filename):\n    subset_list = []\n    with open(join(root_folder, filename)) as f:\n        for line in f:\n            line = line.strip()\n            if (len(line) == 0):\n                continue\n            subset_list.append(normpath(join(root_folder, line)))\n    return set(subset_list)\n\n\ndef load_data_from_folder(root_folder):\n    filenames, class_ids, classes = __load_audio_filenames_with_class__(root_folder)\n    dataset_size = len(filenames)\n    X_train = []\n    y_train = []\n    X_test = []\n    y_test = []\n    X_validation = []\n    y_validation = []\n    pool = Pool(cpu_count() - 1)\n    for (results, filepath, class_id, random_roll) in tqdm(pool.imap_unordered(process_file, zip_longest(filenames, class_ids)), total=dataset_size):\n        filepath = normpath(filepath)\n        is_testing = 1 <= random_roll and random_roll <= 10\n        is_validation = 11 <= random_roll and random_roll <= 20\n        for item in results:\n            if (is_testing):\n                X_test.append(item)\n                y_test.append(class_id)\n            elif (is_validation):\n                X_validation.append(item)\n                y_validation.append(class_id)\n            else:\n                X_train.append(item)\n                y_train.append(class_id)\n    X_train = np.array(X_train)\n    y_train = np.array(y_train)\n    X_test = np.array(X_test)\n    y_test = np.array(y_test)\n    X_validation = np.array(X_validation)\n    y_validation = np.array(y_validation)\n    return X_train, y_train, X_test, y_test, X_validation, y_validation, classes\n\nX_train, y_train, X_test, y_test, X_validation, y_validation, classes = load_data_from_folder('dataset')\nnum_classes = len(classes)\nprint(num_classes)\n(num_train, input_length, num_channel) = X_train.shape\nnum_test = X_test.shape[0]\nnum_validation = X_validation.shape[0]\nmodel_14 = get_tc_resnet_8((input_length, num_channel), num_classes, 1.5)\nmodel_14.compile(optimizer=Adam(),loss='sparse_categorical_crossentropy', metrics=['accuracy'])\n#checkpoint_cb = ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.h5', save_weights_only=True, period=5)\nmodel_14.fit(x=X_train, y=y_train, batch_size=1024, epochs=100, validation_data=(X_test, y_test))#, callbacks=[checkpoint_cb])\nprint(model_14.evaluate(X_validation, y_validation))\nmodel_14.save_weights('weights.h5')\nfiles.download('weights.h5') \n"

# %%
# Make a bottle neck model

original_model    = get_tc_resnet_8((321, 40), 30, 1.5) #model corresponding to kws on google speech cmds: input length, num_channel, num_classes
original_model.load_weights('weights.h5') #Assuming this file is loaded in the current working dir
bottleneck_input  = original_model.get_layer(index=0).input
print(bottleneck_input)
bottleneck_output = original_model.get_layer(index=-2).output
print(bottleneck_output)
bottleneck_model  = Model(inputs=bottleneck_input,outputs=bottleneck_output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 321, 40), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 2808), dtype=tf.float32, name=None), name='dropout_1/Identity:0', description="created by layer 'dropout_1'")

# %%
# Add the last softmax layer
for layer in bottleneck_model.layers:
    layer.trainable = False

new_model = Sequential()
new_model.add(bottleneck_model)
kws_classes = 100
new_model.add(Dense(kws_classes, activation="softmax", input_dim=2808))

# %% [markdown]
# Following 5 cells to load the Competition dataset (train)

# %%
# !mkdir dataset1
# Out:
# mkdir: cannot create directory ‘dataset1’: File exists

# %%
cd dataset1/
# Out:
# /content/TC-ResNet/dataset1

# %%
# !gdown --id 1w4Bn038sLxuv9PKswk2KorCUmgPNup3c
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1w4Bn038sLxuv9PKswk2KorCUmgPNup3c
# To: /content/TC-ResNet/dataset1/train.zip
# 211MB [00:01, 116MB/s]

# %%
# !unzip train.zip

# %%
cd ..
# Out:
# /content/TC-ResNet

# %% [markdown]
# Load the _background_noise folder in dataset1/train

# %%
AUDIO_LENGTH = 2

seed(163)


def __load_background_noises__(root_folder):
    noises = []
    noise_folder = join(root_folder, '_background_noise_')
    for item in listdir(noise_folder):
        if (not item.endswith('.wav')):
            continue
        samples, sr = librosa.load(join(noise_folder, item), sr=None)
        noises.append(samples)
    return noises


noises = __load_background_noises__('dataset1/train')


def generate_noisy_sample(samples, noise):
    samples_length = len(samples)
    noise_length = len(noise)
    if (noise_length < samples_length):
        return samples
    noise_start = random.randint(0, noise_length - samples_length - 1)
    noise_part = noise[noise_start:noise_start + samples_length]
    noise_coeff = random.uniform(0.0, 0.1)
    audio_offset = math.floor(
        random.uniform(-samples_length * 0.1, samples_length * 0.1))
    new_samples = np.zeros((samples_length))
    if (audio_offset >= 0):
        new_samples[audio_offset:] = samples[:samples_length - audio_offset]
    else:
        new_samples[:samples_length + audio_offset] = samples[-audio_offset:]
    new_samples = noise_part * noise_coeff + \
        (1.0 - noise_coeff) * new_samples
    return new_samples


def get_mfcc(samples, sr):
    return librosa.feature.mfcc(samples, sr=sr, n_mfcc=40, n_fft=400, hop_length=100).transpose()


def process_file(argv):
    (filepath, class_id) = argv
    results = []
    samples, sr = librosa.load(filepath, sr=None)
    samples_len = len(samples)
    if (samples_len > sr * AUDIO_LENGTH):
        samples = samples[- sr * AUDIO_LENGTH:]
    elif (samples_len < sr * AUDIO_LENGTH):
        temp = np.zeros((sr * AUDIO_LENGTH))
        temp[:samples_len] = samples
        samples = temp
    mfcc = get_mfcc(samples, sr)
    results.append(mfcc)
    random_roll = randint(1, 100)
    is_testing = 1 <= random_roll and random_roll <= 10
    is_validation = 11 <= random_roll and random_roll <= 20
    if (not is_testing and not is_validation):
        for item in noises:
            new_samples = generate_noisy_sample(samples, item)
            mfcc = get_mfcc(new_samples, sr)
            results.append(mfcc)
    return results, filepath, class_id, random_roll

# %%
def __load_new_audio_filenames_with_class__(root_folder):
    classes = [item for item in listdir(root_folder) if item.startswith('T')] #classes as "T00xx"
    filenames = []
    class_ids = []
    for i in range(len(classes)):
        c = classes[i] 
        class_filenames = __load_new_audio_filenames__((join(root_folder, c, "enrollment"))) #location of wav files for kws
        filenames.extend(class_filenames)
        class_ids.extend([i] * len(class_filenames))
    return filenames, class_ids, classes


def __load_new_audio_filenames__(root_folder):
    filenames = []
    for entry in listdir(root_folder):
        full_path = join(root_folder, entry)
        if (isfile(full_path)):
            if (entry.endswith('.wav')):
                filenames.append(full_path)
        else:
            filenames.extend(__load_audio_filenames__(full_path))
        #if (len(filenames) >= 10):
            #break
    return filenames

def load_new_data_from_folder(root_folder):
    filenames, class_ids, classes = __load_new_audio_filenames_with_class__(root_folder)
    dataset_size = len(filenames)
    X_train = []
    y_train = []
    X_test = []
    y_test = []
    X_validation = []
    y_validation = []
    pool = Pool(cpu_count() - 1)
    for (results, filepath, class_id, random_roll) in tqdm(pool.imap_unordered(process_file, zip_longest(filenames, class_ids)), total=dataset_size):
        filepath = normpath(filepath)
        is_testing = 1 <= random_roll and random_roll <= 10 #vary these to modify train-val-test lengths
        is_validation = 11 <= random_roll and random_roll <=20
        for item in results:
            if (is_testing):
                X_test.append(item)
                y_test.append(class_id)
            elif (is_validation):
                X_validation.append(item)
                y_validation.append(class_id)
                X_test.append(item)
                y_test.append(class_id)
            else:
                X_train.append(item)
                y_train.append(class_id)
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    X_validation = np.array(X_validation)
    y_validation = np.array(y_validation)
    return X_train, y_train, X_test, y_test, X_validation, y_validation, classes

X_train, y_train, X_test, y_test, X_validation, y_validation, classes = load_new_data_from_folder('dataset1/train')
num_classes = len(classes)
(num_train, input_length, num_channel) = X_train.shape
num_test = X_test.shape[0]
num_validation = X_validation.shape[0]
print(num_classes)
print(num_train)
print(num_test)
print(num_validation)
# Out:
# 100%|██████████| 1000/1000 [00:59<00:00, 16.93it/s]
# 100
# 5530
# 210
# 124

# %%
new_model.compile(optimizer=Adam(),loss='sparse_categorical_crossentropy', metrics=['accuracy'])
new_model.fit(x=X_train, y=y_train, batch_size=512, epochs=500, validation_data=(X_test, y_test))
print(new_model.evaluate(X_validation, y_validation))
new_model.save_weights('new_weights.h5')
# Out:
# Epoch 1/500
# 11/11 [==============================] - 2s 65ms/step - loss: 5.5714 - accuracy: 0.0751 - val_loss: 1.9001 - val_accuracy: 0.5429
# Epoch 2/500
# 11/11 [==============================] - 0s 30ms/step - loss: 1.9883 - accuracy: 0.5031 - val_loss: 0.9612 - val_accuracy: 0.7714
# Epoch 3/500
# 11/11 [==============================] - 0s 28ms/step - loss: 1.0350 - accuracy: 0.7294 - val_loss: 0.7833 - val_accuracy: 0.8190
# Epoch 4/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.6984 - accuracy: 0.8186 - val_loss: 0.6354 - val_accuracy: 0.8429
# Epoch 5/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5441 - accuracy: 0.8619 - val_loss: 0.7052 - val_accuracy: 0.8429
# Epoch 6/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.4370 - accuracy: 0.8919 - val_loss: 0.5955 - val_accuracy: 0.8381
# Epoch 7/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.
500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.9543 - val_accuracy: 0.8571
# Epoch 221/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 0.9623 - val_accuracy: 0.8571
# Epoch 222/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.9693 - val_accuracy: 0.8619
# Epoch 223/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0130 - accuracy: 0.9971 - val_loss: 0.9861 - val_accuracy: 0.8714
# Epoch 224/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0087 - accuracy: 0.9982 - val_loss: 1.0163 - val_accuracy: 0.8619
# Epoch 225/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 0.9740 - val_accuracy: 0.8619
# Epoch 226/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0096 - accuracy: 0.9977 - val_loss: 0.9425 - val_accuracy: 0.8619
# Epoch 227/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0080 - accuracy: 0.9985 - val_loss: 0.9751 - val_accuracy: 0.8619
# Epoch 228/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 1.0122 - val_accuracy: 0.8667
# Epoch 229/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 1.0096 - val_accuracy: 0.8619
# Epoch 230/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 1.0210 - val_accuracy: 0.8524
# Epoch 231/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 1.0222 - val_accuracy: 0.8476
# Epoch 232/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 1.0038 - val_accuracy: 0.8524
# Epoch 233/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 0.9801 - val_accuracy: 0.8619
# Epoch 234/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0106 - accuracy: 0.9978 - val_loss: 1.0458 - val_accuracy: 0.8619
# Epoch 235/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0147 - accuracy: 0.9972 - val_loss: 1.0119 - val_accuracy: 0.8667
# Epoch 236/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 1.0184 - val_accuracy: 0.8667
# Epoch 237/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0130 - accuracy: 0.9975 - val_loss: 0.9675 - val_accuracy: 0.8714
# Epoch 238/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0160 - accuracy: 0.9963 - val_loss: 1.0290 - val_accuracy: 0.8619
# Epoch 239/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 1.0108 - val_accuracy: 0.8619
# Epoch 240/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0095 - accuracy: 0.9981 - val_loss: 0.9538 - val_accuracy: 0.8619
# Epoch 241/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0091 - accuracy: 0.9981 - val_loss: 0.9566 - val_accuracy: 0.8571
# Epoch 242/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 1.0062 - val_accuracy: 0.8571
# Epoch 243/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 0.9905 - val_accuracy: 0.8619
# Epoch 244/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 1.0182 - val_accuracy: 0.8619
# Epoch 245/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0105 - accuracy: 0.9974 - val_loss: 1.0299 - val_accuracy: 0.8667
# Epoch 246/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0105 - accuracy: 0.9978 - val_loss: 1.0049 - val_accuracy: 0.8667
# Epoch 247/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 1.0075 - val_accuracy: 0.8714
# Epoch 248/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0132 - accuracy: 0.9973 - val_loss: 1.0201 - val_accuracy: 0.8714
# Epoch 249/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0118 - accuracy: 0.9979 - val_loss: 1.0033 - val_accuracy: 0.8714
# Epoch 250/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 1.0104 - val_accuracy: 0.8762
# Epoch 251/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0137 - accuracy: 0.9975 - val_loss: 1.0749 - val_accuracy: 0.8714
# Epoch 252/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0082 - accuracy: 0.9984 - val_loss: 1.0350 - val_accuracy: 0.8714
# Epoch 253/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 1.0192 - val_accuracy: 0.8667
# Epoch 254/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.9831 - val_accuracy: 0.8667
# Epoch 255/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 1.0362 - val_accuracy: 0.8667
# Epoch 256/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 1.0062 - val_accuracy: 0.8619
# Epoch 257/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0139 - accuracy: 0.9970 - val_loss: 0.9822 - val_accuracy: 0.8714
# Epoch 258/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0122 - accuracy: 0.9974 - val_loss: 1.0095 - val_accuracy: 0.8667
# Epoch 259/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.9894 - val_accuracy: 0.8714
# Epoch 260/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 1.0253 - val_accuracy: 0.8667
# Epoch 261/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0068 - accuracy: 0.9988 - val_loss: 1.0227 - val_accuracy: 0.8714
# Epoch 262/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0111 - accuracy: 0.9982 - val_loss: 1.0216 - val_accuracy: 0.8667
# Epoch 263/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.9615 - val_accuracy: 0.8714
# Epoch 264/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0122 - accuracy: 0.9970 - val_loss: 1.0185 - val_accuracy: 0.8619
# Epoch 265/500
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0145 - accuracy: 0.9965 - val_loss: 0.9861 - val_accuracy: 0.8714
# Epoch 266/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0151 - accuracy: 0.9965 - val_loss: 1.0292 - val_accuracy: 0.8667
# Epoch 267/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 1.0712 - val_accuracy: 0.8571
# Epoch 268/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 1.0238 - val_accuracy: 0.8667
# Epoch 269/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.9934 - val_accuracy: 0.8667
# Epoch 270/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 1.0203 - val_accuracy: 0.8619
# Epoch 271/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 1.0061 - val_accuracy: 0.8619
# Epoch 272/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 1.0141 - val_accuracy: 0.8667
# Epoch 273/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 1.0510 - val_accuracy: 0.8571
# Epoch 274/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0171 - accuracy: 0.9965 - val_loss: 1.0175 - val_accuracy: 0.8571
# Epoch 275/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 1.0255 - val_accuracy: 0.8571
# Epoch 276/500
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 1.0358 - val_accuracy: 0.8619
# Epoch 277/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0084 - accuracy: 0.9987 - val_loss: 1.0476 - val_accuracy: 0.8667
# Epoch 278/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 1.0548 - val_accuracy: 0.8619
# Epoch 279/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0119 - accuracy: 0.9969 - val_loss: 1.0136 - val_accuracy: 0.8714
# Epoch 280/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 1.0458 - val_accuracy: 0.8619
# Epoch 281/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 1.0684 - val_accuracy: 0.8619
# Epoch 282/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0090 - accuracy: 0.9987 - val_loss: 1.0530 - val_accuracy: 0.8571
# Epoch 283/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 1.0254 - val_accuracy: 0.8619
# Epoch 284/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 1.0403 - val_accuracy: 0.8667
# Epoch 285/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 1.0523 - val_accuracy: 0.8571
# Epoch 286/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0111 - accuracy: 0.9974 - val_loss: 1.0387 - val_accuracy: 0.8619
# Epoch 287/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 1.0398 - val_accuracy: 0.8714
# Epoch 288/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0100 - accuracy: 0.9977 - val_loss: 1.1152 - val_accuracy: 0.8571
# Epoch 289/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0109 - accuracy: 0.9981 - val_loss: 1.1102 - val_accuracy: 0.8571
# Epoch 290/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 1.0878 - val_accuracy: 0.8619
# Epoch 291/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 1.0520 - val_accuracy: 0.8762
# Epoch 292/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0135 - accuracy: 0.9968 - val_loss: 1.0939 - val_accuracy: 0.8714
# Epoch 293/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0128 - accuracy: 0.9967 - val_loss: 1.0622 - val_accuracy: 0.8619
# Epoch 294/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0119 - accuracy: 0.9977 - val_loss: 1.0538 - val_accuracy: 0.8667
# Epoch 295/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 1.0663 - val_accuracy: 0.8619
# Epoch 296/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 1.1032 - val_accuracy: 0.8667
# Epoch 297/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 1.0736 - val_accuracy: 0.8667
# Epoch 298/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0102 - accuracy: 0.9979 - val_loss: 1.0805 - val_accuracy: 0.8571
# Epoch 299/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0149 - accuracy: 0.9959 - val_loss: 1.0642 - val_accuracy: 0.8619
# Epoch 300/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 1.0399 - val_accuracy: 0.8619
# Epoch 301/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0089 - accuracy: 0.9979 - val_loss: 1.1093 - val_accuracy: 0.8429
# Epoch 302/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 1.1731 - val_accuracy: 0.8381
# Epoch 303/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 1.1118 - val_accuracy: 0.8429
# Epoch 304/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 1.0856 - val_accuracy: 0.8476
# Epoch 305/500
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 1.1050 - val_accuracy: 0.8619
# Epoch 306/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0078 - accuracy: 0.9985 - val_loss: 1.0698 - val_accuracy: 0.8667
# Epoch 307/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 1.0464 - val_accuracy: 0.8667
# Epoch 308/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 1.0660 - val_accuracy: 0.8714
# Epoch 309/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0087 - accuracy: 0.9979 - val_loss: 1.1405 - val_accuracy: 0.8571
# Epoch 310/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 1.1396 - val_accuracy: 0.8619
# Epoch 311/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 1.1688 - val_accuracy: 0.8619
# Epoch 312/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0110 - accuracy: 0.9972 - val_loss: 1.1965 - val_accuracy: 0.8619
# Epoch 313/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 1.1808 - val_accuracy: 0.8667
# Epoch 314/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 1.0997 - val_accuracy: 0.8714
# Epoch 315/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0144 - accuracy: 0.9972 - val_loss: 1.0834 - val_accuracy: 0.8667
# Epoch 316/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 1.1551 - val_accuracy: 0.8619
# Epoch 317/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0144 - accuracy: 0.9967 - val_loss: 1.1319 - val_accuracy: 0.8619
# Epoch 318/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 1.1288 - val_accuracy: 0.8571
# Epoch 319/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0096 - accuracy: 0.9980 - val_loss: 1.1324 - val_accuracy: 0.8667
# Epoch 320/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 1.0937 - val_accuracy: 0.8619
# Epoch 321/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 1.0797 - val_accuracy: 0.8667
# Epoch 322/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0079 - accuracy: 0.9989 - val_loss: 1.0995 - val_accuracy: 0.8667
# Epoch 323/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 1.1052 - val_accuracy: 0.8619
# Epoch 324/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 1.1065 - val_accuracy: 0.8667
# Epoch 325/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0136 - accuracy: 0.9969 - val_loss: 1.1126 - val_accuracy: 0.8619
# Epoch 326/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0128 - accuracy: 0.9970 - val_loss: 1.0461 - val_accuracy: 0.8667
# Epoch 327/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 1.1124 - val_accuracy: 0.8619
# Epoch 328/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0188 - accuracy: 0.9953 - val_loss: 1.0786 - val_accuracy: 0.8524
# Epoch 329/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 1.1005 - val_accuracy: 0.8524
# Epoch 330/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 1.0999 - val_accuracy: 0.8714
# Epoch 331/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 1.1766 - val_accuracy: 0.8619
# Epoch 332/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0086 - accuracy: 0.9985 - val_loss: 1.1559 - val_accuracy: 0.8619
# Epoch 333/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 1.1147 - val_accuracy: 0.8619
# Epoch 334/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0139 - accuracy: 0.9965 - val_loss: 1.1299 - val_accuracy: 0.8524
# ...
# Epoch 391/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 1.1422 - val_accuracy: 0.8571
# Epoch 392/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0156 - accuracy: 0.9959 - val_loss: 1.1619 - val_accuracy: 0.8667
# Epoch 393/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 1.2316 - val_accuracy: 0.8619
# Epoch 394/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0097 - accuracy: 0.9959 - val_loss: 1.2370 - val_accuracy: 0.8524
# Epoch 395/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 1.2048 - val_accuracy: 0.8571
# Epoch 396/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 1.1978 - val_accuracy: 0.8667
# Epoch 397/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0148 - accuracy: 0.9965 - val_loss: 1.1860 - val_accuracy: 0.8667
# Epoch 398/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0117 - accuracy: 0.9975 - val_loss: 1.1904 - val_accuracy: 0.8571
# Epoch 399/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 1.2174 - val_accuracy: 0.8476
# Epoch 400/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 1.2495 - val_accuracy: 0.8524
# Epoch 401/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 1.2007 - val_accuracy: 0.8571
# Epoch 402/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 1.2370 - val_accuracy: 0.8476
# Epoch 403/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 1.2292 - val_accuracy: 0.8524
# Epoch 404/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0100 - accuracy: 0.9987 - val_loss: 1.2552 - val_accuracy: 0.8476
# Epoch 405/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0100 - accuracy: 0.9977 - val_loss: 1.1773 - val_accuracy: 0.8571
# Epoch 406/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0155 - accuracy: 0.9963 - val_loss: 1.2910 - val_accuracy: 0.8429
# Epoch 407/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 1.2791 - val_accuracy: 0.8667
# Epoch 408/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0107 - accuracy: 0.9975 - val_loss: 1.1778 - val_accuracy: 0.8476
# Epoch 409/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 1.1904 - val_accuracy: 0.8571
# Epoch 410/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0107 - accuracy: 0.9976 - val_loss: 1.1351 - val_accuracy: 0.8667
# Epoch 411/500
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0134 - accuracy: 0.9971 - val_loss: 1.1284 - val_accuracy: 0.8667
# Epoch 412/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 1.1405 - val_accuracy: 0.8714
# Epoch 413/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 1.1171 - val_accuracy: 0.8762
# Epoch 414/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 1.1178 - val_accuracy: 0.8524
# Epoch 415/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 1.2096 - val_accuracy: 0.8667
# Epoch 416/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0097 - accuracy: 0.9973 - val_loss: 1.2824 - val_accuracy: 0.8571
# Epoch 417/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 1.2417 - val_accuracy: 0.8524
# Epoch 418/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0089 - accuracy: 0.9980 - val_loss: 1.2296 - val_accuracy: 0.8429
# Epoch 419/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 1.2569 - val_accuracy: 0.8524
# Epoch 420/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 1.2369 - val_accuracy: 0.8476
# Epoch 421/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0113 - accuracy: 0.9977 - val_loss: 1.2428 - val_accuracy: 0.8619
# Epoch 422/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 1.2311 - val_accuracy: 0.8524
# Epoch 423/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 1.2397 - val_accuracy: 0.8571
# Epoch 424/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 1.2134 - val_accuracy: 0.8524
# Epoch 425/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 1.2380 - val_accuracy: 0.8476
# Epoch 426/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 1.2149 - val_accuracy: 0.8571
# Epoch 427/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0098 - accuracy: 0.9985 - val_loss: 1.2112 - val_accuracy: 0.8524
# Epoch 428/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 1.2562 - val_accuracy: 0.8524
# Epoch 429/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 1.1647 - val_accuracy: 0.8667
# Epoch 430/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 1.1336 - val_accuracy: 0.8619
# Epoch 431/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0091 - accuracy: 0.9968 - val_loss: 1.2377 - val_accuracy: 0.8619
# Epoch 432/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 1.2321 - val_accuracy: 0.8619
# Epoch 433/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0089 - accuracy: 0.9982 - val_loss: 1.2099 - val_accuracy: 0.8619
# Epoch 434/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0094 - accuracy: 0.9978 - val_loss: 1.2082 - val_accuracy: 0.8571
# Epoch 435/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0114 - accuracy: 0.9972 - val_loss: 1.1721 - val_accuracy: 0.8524
# Epoch 436/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 1.2073 - val_accuracy: 0.8667
# Epoch 437/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 1.3183 - val_accuracy: 0.8619
# Epoch 438/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 1.3036 - val_accuracy: 0.8476
# Epoch 439/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 1.2841 - val_accuracy: 0.8476
# Epoch 440/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 1.2995 - val_accuracy: 0.8571
# Epoch 441/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0100 - accuracy: 0.9975 - val_loss: 1.2624 - val_accuracy: 0.8571
# Epoch 442/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 1.2503 - val_accuracy: 0.8524
# Epoch 443/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 1.2724 - val_accuracy: 0.8524
# Epoch 444/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 1.2498 - val_accuracy: 0.8381
# Epoch 445/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 1.3338 - val_accuracy: 0.8476
# Epoch 446/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 1.3090 - val_accuracy: 0.8571
# Epoch 447/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 1.3050 - val_accuracy: 0.8571
# Epoch 448/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0127 - accuracy: 0.9975 - val_loss: 1.2763 - val_accuracy: 0.8571
# Epoch 449/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 1.2736 - val_accuracy: 0.8667
# Epoch 450/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0132 - accuracy: 0.9965 - val_loss: 1.2899 - val_accuracy: 0.8429
# Epoch 451/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 1.3919 - val_accuracy: 0.8286
# Epoch 452/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0105 - accuracy: 0.9970 - val_loss: 1.2607 - val_accuracy: 0.8571
# Epoch 453/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0128 - accuracy: 0.9974 - val_loss: 1.2535 - val_accuracy: 0.8619
# Epoch 454/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 1.2360 - val_accuracy: 0.8571
# Epoch 455/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 1.2110 - val_accuracy: 0.8571
# Epoch 456/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0160 - accuracy: 0.9965 - val_loss: 1.2573 - val_accuracy: 0.8619
# Epoch 457/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0104 - accuracy: 0.9977 - val_loss: 1.3012 - val_accuracy: 0.8619
# Epoch 458/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0095 - accuracy: 0.9977 - val_loss: 1.3347 - val_accuracy: 0.8571
# Epoch 459/500
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 1.2104 - val_accuracy: 0.8667
# Epoch 460/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 1.2643 - val_accuracy: 0.8571
# Epoch 461/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 1.2496 - val_accuracy: 0.8571
# Epoch 462/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 1.2518 - val_accuracy: 0.8571
# Epoch 463/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 1.2696 - val_accuracy: 0.8476
# Epoch 464/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 1.3164 - val_accuracy: 0.8571
# Epoch 465/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0111 - accuracy: 0.9958 - val_loss: 1.2842 - val_accuracy: 0.8619
# Epoch 466/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 1.2219 - val_accuracy: 0.8619
# Epoch 467/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 1.3315 - val_accuracy: 0.8524
# Epoch 468/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0075 - accuracy: 0.9969 - val_loss: 1.3601 - val_accuracy: 0.8476
# Epoch 469/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 1.3530 - val_accuracy: 0.8524
# Epoch 470/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 1.2989 - val_accuracy: 0.8667
# Epoch 471/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0078 - accuracy: 0.9982 - val_loss: 1.3990 - val_accuracy: 0.8524
# Epoch 472/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 1.4082 - val_accuracy: 0.8524
# Epoch 473/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 1.3824 - val_accuracy: 0.8571
# Epoch 474/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0097 - accuracy: 0.9974 - val_loss: 1.4427 - val_accuracy: 0.8619
# Epoch 475/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 1.3660 - val_accuracy: 0.8571
# Epoch 476/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0129 - accuracy: 0.9969 - val_loss: 1.3091 - val_accuracy: 0.8524
# Epoch 477/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 1.3930 - val_accuracy: 0.8524
# Epoch 478/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 1.3102 - val_accuracy: 0.8619
# Epoch 479/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 1.2735 - val_accuracy: 0.8619
# Epoch 480/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0116 - accuracy: 0.9956 - val_loss: 1.2987 - val_accuracy: 0.8524
# Epoch 481/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0136 - accuracy: 0.9975 - val_loss: 1.3338 - val_accuracy: 0.8476
# Epoch 482/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 1.2925 - val_accuracy: 0.8524
# Epoch 483/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0163 - accuracy: 0.9967 - val_loss: 1.3065 - val_accuracy: 0.8619
# Epoch 484/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 1.2776 - val_accuracy: 0.8619
# Epoch 485/500
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0104 - accuracy: 0.9975 - val_loss: 1.3710 - val_accuracy: 0.8667
# Epoch 486/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 1.4400 - val_accuracy: 0.8571
# Epoch 487/500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 1.3722 - val_accuracy: 0.8571
# Epoch 488/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0092 - accuracy: 0.9957 - val_loss: 1.3727 - val_accuracy: 0.8571
# Epoch 489/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 1.3790 - val_accuracy: 0.8619
# Epoch 490/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0188 - accuracy: 0.9959 - val_loss: 1.4198 - val_accuracy: 0.8571
# Epoch 491/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 1.5296 - val_accuracy: 0.8381
# Epoch 492/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0112 - accuracy: 0.9974 - val_loss: 1.4461 - val_accuracy: 0.8619
# Epoch 493/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 1.3599 - val_accuracy: 0.8524
# Epoch 494/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 1.3821 - val_accuracy: 0.8476
# Epoch 495/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 1.4270 - val_accuracy: 0.8571
# Epoch 496/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 1.4422 - val_accuracy: 0.8619
# Epoch 497/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 1.4334 - val_accuracy: 0.8571
# Epoch 498/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 1.4027 - val_accuracy: 0.8524
# Epoch 499/500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 1.4320 - val_accuracy: 0.8571
# Epoch 500/500
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 1.4805 - val_accuracy: 0.8714
# 4/4 [==============================] - 0s 53ms/step - loss: 1.8193 - accuracy: 0.8468
# [1.8193066120147705, 0.8467742204666138]

# %%
files.download('new_weights.h5')
